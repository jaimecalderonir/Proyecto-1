# %%
import pandas as pd

# %%
life_cont = pd.read_csv('Total_life_by_continents.csv')
life_cont = life_cont.drop(columns=['Unnamed: 0'])

# %%
life_cont.describe()
# Out:
#               Year  Life Expectancy F  Life Expectancy M  \
# count  1122.000000        1122.000000        1122.000000
# mean   2018.500000          74.539501          69.293636
# std       1.708587           7.761088           7.452506
# min    2016.000000          52.230000          49.560000
# 25%    2017.000000          68.622500          63.607500
# 50%    2018.500000          76.280000          69.645000
# 75%    2020.000000          80.500000          74.790000
# max    2021.000000          87.710000          82.100000
#
#        Total Life Expectancy
# count            1122.000000
# mean               71.873627
# std                 7.549658
# min                52.040000
# 25%                66.015000
# 50%                72.770000
# 75%                77.570000
# max                84.560000

# %%
life_cont1 = life_cont.drop(columns = ['Life Expectancy F', 'Life Expectancy M'])
df_espe = df_obesidaddf_obesidad =life_cont1.groupby(['Year', 'Continent']).agg({'Total Life Expectancy': 'mean'}).round(2).reset_index()
df_espe
# Out:
#     Year    Continent  Total Life Expectancy
# 0   2016      América                  74.26
# 1   2016         Asia                  73.70
# 2   2016       Europa                  79.25
# 3   2016  Europa/Asia                  74.88
# 4   2016      Oceanía                  70.29
# 5   2016       África                  63.04
# 6   2017      América                  74.31
# 7   2017         Asia                  74.06
# 8   2017       Europa                  79.34
# 9   2017  Europa/Asia                  75.47
# 10  2017      Oceanía                  70.46
# 11  2017       África                  63.48
# 12  2018      América                  74.54
# 13  2018         Asia                  74.33
# 14  2018       Europa                  79.47
# 15  2018  Europa/Asia                  75.78
# 16  2018      Oceanía                  70.56
# 17  2018       África                  63.76
# 18  2019      América                  74.56
# 19  2019         Asia                  74.54
# ...

# %%
# Calcular la media de la tasa de obesidad por continente
#df_media_continente = life_cont1.groupby('Continent')['Total Life Expectancy'].mean().reset_index()

# Renombrar la columna para mayor claridad
df_espe.rename(columns={'Total Life Expectancy': 'Media Esperanza de vida', 'Continent' : 'Continente', 'Year':'Año'}, inplace=True)

df_espe['Continente']
# Out:
#      Año   Continente  Media Esperanza de vida
# 0   2016      América                    74.26
# 1   2016         Asia                    73.70
# 2   2016       Europa                    79.25
# 3   2016  Europa/Asia                    74.88
# 4   2016      Oceanía                    70.29
# 5   2016       África                    63.04
# 6   2017      América                    74.31
# 7   2017         Asia                    74.06
# 8   2017       Europa                    79.34
# 9   2017  Europa/Asia                    75.47
# 10  2017      Oceanía                    70.46
# 11  2017       África                    63.48
# 12  2018      América                    74.54
# 13  2018         Asia                    74.33
# 14  2018       Europa                    79.47
# 15  2018  Europa/Asia                    75.78
# 16  2018      Oceanía                    70.56
# 17  2018       África                    63.76
# 18  2019      América                    74.56
# ...

# %%
ob =pd.read_csv('Obesity_continents.csv')

# %%
ob1 = ob.drop(columns = ['Unnamed: 0', 'Max', 'Min'])

# %%
ob1
# Out:
#       Year  Obesity Rate Continent
# 0     2021         39.13      Asia
# 1     2020         39.37      Asia
# 2     2019         39.45      Asia
# 3     2018         39.23      Asia
# 4     2017         38.97      Asia
# ...    ...           ...       ...
# 1129  2020         43.82    África
# 1130  2019         43.33    África
# 1131  2018         42.54    África
# 1132  2017         41.68    África
# 1133  2016         41.13    África
#
# [1134 rows x 3 columns]

# %%
df_obesidad = df_obesidaddf_obesidad = ob1.groupby(['Year', 'Continent']).agg({'Obesity Rate': 'mean'}).round(2).reset_index()
df_obesidad
# Out:
#     Year Continent  Obesity Rate
# 0   2016   América         72.03
# 1   2016      Asia         42.12
# 2   2016    Europa        100.48
# 3   2016   Oceanía        106.20
# 4   2016    África         35.79
# 5   2017   América         73.84
# 6   2017      Asia         42.63
# 7   2017    Europa        101.44
# 8   2017   Oceanía        107.81
# 9   2017    África         36.37
# 10  2018   América         76.08
# 11  2018      Asia         43.12
# 12  2018    Europa        102.94
# 13  2018   Oceanía        109.31
# 14  2018    África         37.26
# 15  2019   América         78.78
# 16  2019      Asia         44.21
# 17  2019    Europa        103.51
# 18  2019   Oceanía        111.07
# 19  2019    África         38.12
# 20  2020   América         79.45
# 21  2020      Asia         45.08
# 22  2020    Europa        104.56
# 23  2020   Oceanía        112.25
# 24  2020    África         38.55
# 25  2021   América         80.69
# 26  2021      Asia         45.90
# ...

# %%
# Calcular la media de la tasa de obesidad por continente
#df_media_continente_ob = ob1.groupby('Continent')['Obesity Rate'].mean().reset_index()

# Renombrar la columna para mayor claridad
df_obesidad.rename(columns={'Obesity Rate': 'Media Obesidad', 'Year' : 'Año', 'Continent' : 'Continente'}, inplace=True)

df_obesidad
# Out:
#      Año Continente  Media Obesidad
# 0   2016    América           72.03
# 1   2016       Asia           42.12
# 2   2016     Europa          100.48
# 3   2016    Oceanía          106.20
# 4   2016     África           35.79
# 5   2017    América           73.84
# 6   2017       Asia           42.63
# 7   2017     Europa          101.44
# 8   2017    Oceanía          107.81
# 9   2017     África           36.37
# 10  2018    América           76.08
# 11  2018       Asia           43.12
# 12  2018     Europa          102.94
# 13  2018    Oceanía          109.31
# 14  2018     África           37.26
# 15  2019    América           78.78
# 16  2019       Asia           44.21
# 17  2019     Europa          103.51
# 18  2019    Oceanía          111.07
# 19  2019     África           38.12
# 20  2020    América           79.45
# 21  2020       Asia           45.08
# 22  2020     Europa          104.56
# 23  2020    Oceanía          112.25
# 24  2020     África           38.55
# ...

# %%
df_obesidad['Año'].value_counts()
# Out:
# Año
# 2016    5
# 2017    5
# 2018    5
# 2019    5
# 2020    5
# 2021    5
# Name: count, dtype: int64

# %%
continentes_df1 = set(df_espe['Continente'])
continentes_df2 = set(df_obesidad['Continente'])

continente_a_eliminar = continentes_df1 - continentes_df2
print(continente_a_eliminar)
# Out:
# {'Europa/Asia'}

# %%
# Convertir el set a una lista
continente_a_eliminar = list(continente_a_eliminar)

# Eliminar las filas correspondientes del df1
df1 = df_espe[~df_espe['Continente'].isin(continente_a_eliminar)].reset_index()

df1
# Out:
#     index   Año Continente  Media Esperanza de vida
# 0       0  2016    América                    74.26
# 1       1  2016       Asia                    73.70
# 2       2  2016     Europa                    79.25
# 3       4  2016    Oceanía                    70.29
# 4       5  2016     África                    63.04
# 5       6  2017    América                    74.31
# 6       7  2017       Asia                    74.06
# 7       8  2017     Europa                    79.34
# 8      10  2017    Oceanía                    70.46
# 9      11  2017     África                    63.48
# 10     12  2018    América                    74.54
# 11     13  2018       Asia                    74.33
# 12     14  2018     Europa                    79.47
# 13     16  2018    Oceanía                    70.56
# 14     17  2018     África                    63.76
# 15     18  2019    América                    74.56
# 16     19  2019       Asia                    74.54
# ...

# %%
df_espe['Continente'].value_counts()
# Out:
# Continente
# América        6
# Asia           6
# Europa         6
# Europa/Asia    6
# Oceanía        6
# África         6
# Name: count, dtype: int64

# %%
df_f_f = pd.merge(df1, df_obesidad, on = ['Continente', 'Año'], how = 'outer')

# %%
df_f_f.reset_index().drop(columns = ['index', 'level_0'],inplace=True)

# %%
df_f_f['Media Obesidad']/100
# Out:
# 0     0.7203
# 1     0.7384
# 2     0.7608
# 3     0.7878
# 4     0.7945
# 5     0.8069
# 6     0.4212
# 7     0.4263
# 8     0.4312
# 9     0.4421
# 10    0.4508
# 11    0.4590
# 12    1.0048
# 13    1.0144
# 14    1.0294
# 15    1.0351
# 16    1.0456
# 17    1.0441
# 18    1.0620
# 19    1.0781
# 20    1.0931
# 21    1.1107
# 22    1.1225
# 23    1.1390
# 24    0.3579
# 25    0.3637
# 26    0.3726
# 27    0.3812
# 28    0.3855
# 29    0.3913
# Name: Media Obesidad, dtype: float64

# %%
df_f_f.to_csv('df_cont_unido.csv')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.scatter(x=df_f_f['Media Esperanza de vida'], y = df_f_f['Media Obesidad'])
plt.show()

# %%
matriz_correlacion = df_f_f[['Media Obesidad','Media Esperanza de vida']].corr()
coeficiente_correlacion = matriz_correlacion.loc['Media Obesidad', 'Media Esperanza de vida']

coeficiente_correlacion
# Out:
# 0.535536859272159

# %%
df_f_f
# Out:
#     index   Año Continente  Media Esperanza de vida  Media Obesidad
# 0       0  2016    América                    74.26           72.03
# 1       6  2017    América                    74.31           73.84
# 2      12  2018    América                    74.54           76.08
# 3      18  2019    América                    74.56           78.78
# 4      24  2020    América                    73.64           79.45
# 5      30  2021    América                    72.52           80.69
# 6       1  2016       Asia                    73.70           42.12
# 7       7  2017       Asia                    74.06           42.63
# 8      13  2018       Asia                    74.33           43.12
# 9      19  2019       Asia                    74.54           44.21
# 10     25  2020       Asia                    73.69           45.08
# 11     31  2021       Asia                    73.32           45.90
# 12      2  2016     Europa                    79.25          100.48
# ...

# %%
df_f_f1 = df_f_f.drop(columns = ['Año', 'Continente', 'index'])

# %%
es_cor = df_f_f1.corr()
sns.heatmap(es_cor, annot = True)
plt.show()
