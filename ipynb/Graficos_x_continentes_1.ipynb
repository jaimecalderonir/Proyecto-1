# %%
import pandas as pd
import numpy as np
import requests

# %%
df = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/New_project/Proyecto-1/esperanza_paises_año_M_F_T')

# %%
df['Country'].unique()
# Out:
# array(['afganistan', 'albania', 'alemania', 'andorra', 'angola',
#        'antigua-barbuda', 'arabia-saudita', 'argelia', 'argentina',
#        'armenia', 'australia', 'austria', 'azerbaiyan', 'bahamas',
#        'banglades', 'barbados', 'barein', 'belgica', 'belice', 'benin',
#        'bielorrusia', 'birmania', 'bolivia', 'bosnia-herzegovina',
#        'botsuana', 'brasil', 'brunei', 'bulgaria', 'burkina-faso',
#        'burundi', 'butan', 'cabo-verde', 'camboya', 'camerun', 'canada',
#        'catar', 'chad', 'chile', 'china', 'chipre', 'colombia', 'comoras',
#        'congo', 'corea-del-norte', 'corea-del-sur', 'costa-marfil',
#        'costa-rica', 'croacia', 'cuba', 'dinamarca', 'dominica',
#        'ecuador', 'egipto', 'el-salvador', 'emiratos-arabes-unidos',
#        'eritrea', 'eslovaquia', 'eslovenia', 'espana', 'estonia',
#        'etiopia', 'filipinas', 'finlandia', 'fiyi', 'francia', 'gabon',
#        'gambia', 'georgia', 'ghana', 'granada', 'grecia', 'guatemala',
# ...

# %%
paises_continentes = {
    'afganistan': 'Asia',
    'albania': 'Europa',
    'alemania': 'Europa',
    'andorra': 'Europa',
    'angola': 'África',
    'antigua-barbuda': 'América',
    'arabia-saudita': 'Asia',
    'argelia': 'África',
    'argentina': 'América',
    'armenia': 'Asia',
    'australia': 'Oceanía',
    'austria': 'Europa',
    'azerbaiyan': 'Asia',
    'bahamas': 'América',
    'banglades': 'Asia',
    'barbados': 'América',
    'barein': 'Asia',
    'belgica': 'Europa',
    'belice': 'América',
    'benin': 'África',
    'bielorrusia': 'Europa',
    'birmania': 'Asia',
    'bolivia': 'América',
    'bosnia-herzegovina': 'Europa',
    'botsuana': 'África',
    'brasil': 'América',
    'brunei': 'Asia',
    'bulgaria': 'Europa',
    'burkina-faso': 'África',
    'burundi': 'África',
    'butan': 'Asia',
    'cabo-verde': 'África',
    'camboya': 'Asia',
    'camerun': 'África',
    'canada': 'América',
    'catar': 'Asia',
    'chad': 'África',
    'chile': 'América',
    'china': 'Asia',
    'chipre': 'Asia',
    'colombia': 'América',
    'comoras': 'África',
    'congo': 'África',
    'corea-del-norte': 'Asia',
    'corea-del-sur': 'Asia',
    'costa-marfil': 'África',
    'costa-rica': 'América',
    'croacia': 'Europa',
    'cuba': 'América',
    'dinamarca': 'Europa',
    'dominica': 'América',
    'ecuador': 'América',
    'egipto': 'África',
    'el-salvador': 'América',
    'emiratos-arabes-unidos': 'Asia',
    'eritrea': 'África',
    'eslovaquia': 'Europa',
    'eslovenia': 'Europa',
    'espana': 'Europa',
    'estonia': 'Europa',
    'etiopia': 'África',
    'filipinas': 'Asia',
    'finlandia': 'Europa',
    'fiyi': 'Oceanía',
    'francia': 'Europa',
    'gabon': 'África',
    'gambia': 'África',
    'georgia': 'Asia',
    'ghana': 'África',
    'granada': 'América',
    'grecia': 'Europa',
    'guatemala': 'América',
    'guinea': 'África',
    'guinea-bisau': 'África',
    'guinea-ecuatorial': 'África',
    'guyana': 'América',
    'haiti': 'América',
    'honduras': 'América',
    'hungria': 'Europa',
    'india': 'Asia',
    'indonesia': 'Asia',
    'irak': 'Asia',
    'iran': 'Asia',
    'irlanda': 'Europa',
    'islandia': 'Europa',
    'islas-marshall': 'Oceanía',
    'islas-salomon': 'Oceanía',
    'israel': 'Asia',
    'italia': 'Europa',
    'jamaica': 'América',
    'japon': 'Asia',
    'jordania': 'Asia',
    'kazajistan': 'Asia',
    'kenia': 'África',
    'kirguistan': 'Asia',
    'kiribati': 'Oceanía',
    'kuwait': 'Asia',
    'laos': 'Asia',
    'lesoto': 'África',
    'letonia': 'Europa',
    'libano': 'Asia',
    'liberia': 'África',
    'libia': 'África',
    'lituania': 'Europa',
    'luxemburgo': 'Europa',
    'macedonia': 'Europa',
    'madagascar': 'África',
    'malasia': 'Asia',
    'malaui': 'África',
    'maldivas': 'Asia',
    'mali': 'África',
    'malta': 'Europa',
    'marruecos': 'África',
    'mauricio': 'África',
    'mauritania': 'África',
    'mexico': 'América',
    'micronesia': 'Oceanía',
    'moldavia': 'Europa',
    'mongolia': 'Asia',
    'montenegro': 'Europa',
    'mozambique': 'África',
    'namibia': 'África',
    'nauru': 'Oceanía',
    'nepal': 'Asia',
    'nicaragua': 'América',
    'niger': 'África',
    'nigeria': 'África',
    'noruega': 'Europa',
    'nueva-zelanda': 'Oceanía',
    'oman': 'Asia',
    'paises-bajos': 'Europa',
    'pakistan': 'Asia',
    'panama': 'América',
    'papua-nueva-guinea': 'Oceanía',
    'paraguay': 'América',
    'peru': 'América',
    'polonia': 'Europa',
    'portugal': 'Europa',
    'republica-centroafricana': 'África',
    'republica-checa': 'Europa',
    'republica-democratica-congo': 'África',
    'republica-dominicana': 'América',
    'ruanda': 'África',
    'rumania': 'Europa',
    'rusia': 'Europa/Asia',
    'samoa': 'Oceanía',
    'san-cristobal-nieves': 'América',
    'san-vicente-las-granadinas': 'América',
    'santa-lucia': 'América',
    'santo-tome-principe': 'África',
    'senegal': 'África',
    'serbia': 'Europa',
    'seychelles': 'África',
    'sierra-leona': 'África',
    'singapur': 'Asia',
    'siria': 'Asia',
    'somalia': 'África',
    'sri-lanka': 'Asia',
    'suazilandia': 'África',
    'sudafrica': 'África',
    'sudan': 'África',
    'suecia': 'Europa',
    'suiza': 'Europa',
    'surinam': 'América',
    'tailandia': 'Asia',
    'tanzania': 'África',
    'tayikistan': 'Asia',
    'timor-oriental': 'Asia',
    'togo': 'África',
    'tonga': 'Oceanía',
    'trinidad-tobago': 'América',
    'tunez': 'África',
    'turkmenistan': 'Asia',
    'turquia': 'Europa/Asia',
    'ucrania': 'Europa',
    'uganda': 'África',
    'uk': 'Europa',
    'uruguay': 'América',
    'usa': 'América',
    'uzbekistan': 'Asia',
    'vanuatu': 'Oceanía',
    'venezuela': 'América',
    'vietnam': 'Asia',
    'yemen': 'Asia',
    'yibuti': 'África',
    'zambia': 'África',
    'zimbabue': 'África'
}

# %%
df['Continent'] = df['Country'].map(paises_continentes)

# %%
df
# Out:
#          Country  Year Life Expectancy F Life Expectancy M  \
# 0     afganistan  2021             65,28             58,92
# 1     afganistan  2020             65,43             59,87
# 2     afganistan  2019             66,68             60,62
# 3     afganistan  2018             66,46             59,92
# 4     afganistan  2017             66,10             60,11
# ...          ...   ...               ...               ...
# 1117    zimbabue  2020             63,86             58,13
# 1118    zimbabue  2019             63,66             58,64
# 1119    zimbabue  2018             63,59             58,97
# 1120    zimbabue  2017             62,96             58,21
# 1121    zimbabue  2016             62,42             57,96
#
#      Total Life Expectancy Continent
# 0                    61,98      Asia
# 1                    62,58      Asia
# 2                    63,57      Asia
# 3                    63,08      Asia
# 4                    63,02      Asia
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.dtypes
# Out:
# Country                  object
# Year                      int64
# Life Expectancy F        object
# Life Expectancy M        object
# Total Life Expectancy    object
# Continent                object
# dtype: object

# %%
df['Life Expectancy F'] = df['Life Expectancy F'].apply(lambda x: float(x.replace(',', '.')))

# Mostrar el DataFrame resultante
df
# Out:
#          Country  Year  Life Expectancy F Life Expectancy M  \
# 0     afganistan  2021              65.28             58,92
# 1     afganistan  2020              65.43             59,87
# 2     afganistan  2019              66.68             60,62
# 3     afganistan  2018              66.46             59,92
# 4     afganistan  2017              66.10             60,11
# ...          ...   ...                ...               ...
# 1117    zimbabue  2020              63.86             58,13
# 1118    zimbabue  2019              63.66             58,64
# 1119    zimbabue  2018              63.59             58,97
# 1120    zimbabue  2017              62.96             58,21
# 1121    zimbabue  2016              62.42             57,96
#
#      Total Life Expectancy Continent
# 0                    61,98      Asia
# 1                    62,58      Asia
# 2                    63,57      Asia
# 3                    63,08      Asia
# 4                    63,02      Asia
# ...

# %%
df['Life Expectancy M'] = df['Life Expectancy M'].apply(lambda x: float(x.replace(',', '.')))

# %%
df['Total Life Expectancy'] = df['Total Life Expectancy'].apply(lambda x: float(x.replace(',', '.')))
df.dtypes
# Out:
# Country                   object
# Year                       int64
# Life Expectancy F        float64
# Life Expectancy M        float64
# Total Life Expectancy    float64
# Continent                 object
# dtype: object

# %%
df['Year'] = df['Year'].astype(str)

# %%
df1 = df.round(2)

# %%
'''df_pivot = df.pivot_table(index=['Continent'],
                           columns=['Total Life Expectancy'],
                           values='Total Life Expectancy').reset_index()

df_pivot.columns.name = None

df_pivot'''
# Out:
# "df_pivot = df.pivot_table(index=['Continent'],\n                           columns=['Total Life Expectancy'],\n                           values='Total Life Expectancy').reset_index()\n\ndf_pivot.columns.name = None\n\ndf_pivot"

# %%
sns.barplot(x="Continent", y="Total Life Expectancy", data = df1 )
plt.show()

# %%
sns.boxplot(x = 'Continent',y='Total Life Expectancy', data=df1)
plt.show()

# %%
df_cont = df1.drop(columns='Country')

# %%
df_cont.to_csv('Total_life_by_continents.csv')

# %%
cont = df_cont.groupby('Continent')

# %%
sns.distplot(df_cont['Total Life Expectancy'], bins=50)
plt.show()
# Out:
# /var/folders/zc/6rc7nzhj13scy5qssxw2pjlh0000gn/T/ipykernel_2588/3477479545.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_cont['Total Life Expectancy'], bins=50)

# %%
df3 = pd.read_csv('Obesidad_paises_año_VALOR_MAX_MIN2.csv')

# %%
df3
# Out:
#          Country  Year  Value    Max    Min
# 0     afganistan  2021  39.13  63.65  20.86
# 1     afganistan  2020  39.37  64.19  20.91
# 2     afganistan  2019  39.45  63.80  20.91
# 3     afganistan  2018  39.23  63.66  20.90
# 4     afganistan  2017  38.97  62.35  21.38
# ...          ...   ...    ...    ...    ...
# 1129    zimbabue  2020  43.82  70.76  23.64
# 1130    zimbabue  2019  43.33  69.52  23.34
# 1131    zimbabue  2018  42.54  68.38  22.91
# 1132    zimbabue  2017  41.68  66.68  22.65
# 1133    zimbabue  2016  41.13  65.26  22.51
#
# [1134 rows x 5 columns]

# %%
paises_continentes1 = {
    'afganistan': 'Asia',
    'albania': 'Europa',
    'alemania': 'Europa',
    'andorra': 'Europa',
    'angola': 'África',
    'antigua-barbuda': 'América',
    'arabia-saudita': 'Asia',
    'argelia': 'África',
    'argentina': 'América',
    'armenia': 'Asia',
    'australia': 'Oceanía',
    'austria': 'Europa',
    'azerbaiyan': 'Asia',
    'bahamas': 'América',
    'banglades': 'Asia',
    'barbados': 'América',
    'barein': 'Asia',
    'belgica': 'Europa',
    'belice': 'América',
    'benin': 'África',
    'bielorrusia': 'Europa',
    'birmania': 'Asia',
    'bolivia': 'América',
    'bosnia-herzegovina': 'Europa',
    'botsuana': 'África',
    'brasil': 'América',
    'brunei': 'Asia',
    'bulgaria': 'Europa',
    'burkina-faso': 'África',
    'burundi': 'África',
    'butan': 'Asia',
    'cabo-verde': 'África',
    'camboya': 'Asia',
    'camerun': 'África',
    'canada': 'América',
    'catar': 'Asia',
    'chad': 'África',
    'chile': 'América',
    'china': 'Asia',
    'chipre': 'Asia',
    'colombia': 'América',
    'comoras': 'África',
    'congo': 'África',
    'corea-del-norte': 'Asia',
    'corea-del-sur': 'Asia',
    'costa-marfil': 'África',
    'costa-rica': 'América',
    'croacia': 'Europa',
    'cuba': 'América',
    'dinamarca': 'Europa',
    'dominica': 'América',
    'ecuador': 'América',
    'egipto': 'África',
    'el-salvador': 'América',
    'emiratos-arabes-unidos': 'Asia',
    'eritrea': 'África',
    'eslovaquia': 'Europa',
    'eslovenia': 'Europa',
    'espana': 'Europa',
    'estonia': 'Europa',
    'etiopia': 'África',
    'filipinas': 'Asia',
    'finlandia': 'Europa',
    'fiyi': 'Oceanía',
    'francia': 'Europa',
    'gabon': 'África',
    'gambia': 'África',
    'georgia': 'Asia',
    'ghana': 'África',
    'granada': 'América',
    'grecia': 'Europa',
    'guatemala': 'América',
    'guinea': 'África',
    'guinea-bisau': 'África',
    'guinea-ecuatorial': 'África',
    'guyana': 'América',
    'haiti': 'América',
    'honduras': 'América',
    'hungria': 'Europa',
    'india': 'Asia',
    'indonesia': 'Asia',
    'irak': 'Asia',
    'iran': 'Asia',
    'irlanda': 'Europa',
    'islandia': 'Europa',
    'islas-marshall': 'Oceanía',
    'islas-salomon': 'Oceanía',
    'israel': 'Asia',
    'italia': 'Europa',
    'jamaica': 'América',
    'japon': 'Asia',
    'jordania': 'Asia',
    'kazajistan': 'Asia',
    'kenia': 'África',
    'kirguistan': 'Asia',
    'kiribati': 'Oceanía',
    'kuwait': 'Asia',
    'laos': 'Asia',
    'lesoto': 'África',
    'letonia': 'Europa',
    'libano': 'Asia',
    'liberia': 'África',
    'libia': 'África',
    'lituania': 'Europa',
    'luxemburgo': 'Europa',
    'macedonia': 'Europa',
    'madagascar': 'África',
    'malasia': 'Asia',
    'malaui': 'África',
    'maldivas': 'Asia',
    'mali': 'África',
    'malta': 'Europa',
    'marruecos': 'África',
    'mauricio': 'África',
    'mauritania': 'África',
    'mexico': 'América',
    'micronesia': 'Oceanía',
    'moldavia': 'Europa',
    'mongolia': 'Asia',
    'montenegro': 'Europa',
    'mozambique': 'África',
    'namibia': 'África',
    'nauru': 'Oceanía',
    'nepal': 'Asia',
    'nicaragua': 'América',
    'niger': 'África',
    'nigeria': 'África',
    'noruega': 'Europa',
    'nueva-zelanda': 'Oceanía',
    'oman': 'Asia',
    'paises-bajos': 'Europa',
    'pakistan': 'Asia',
    'panama': 'América',
    'papua-nueva-guinea': 'Oceanía',
    'paraguay': 'América',
    'peru': 'América',
    'polonia': 'Europa',
    'portugal': 'Europa',
    'republica-centroafricana': 'África',
    'republica-checa': 'Europa',
    'republica-democratica-congo': 'África',
    'republica-dominicana': 'América',
    'ruanda': 'África',
    'rumania': 'Europa',
    'rusia': 'Europa',
    'samoa': 'Oceanía',
    'san-cristobal-nieves': 'América',
    'san-vicente-las-granadinas': 'América',
    'santa-lucia': 'América',
    'santo-tome-principe': 'África',
    'senegal': 'África',
    'serbia': 'Europa',
    'seychelles': 'África',
    'sierra-leona': 'África',
    'singapur': 'Asia',
    'siria': 'Asia',
    'somalia': 'África',
    'sri-lanka': 'Asia',
    'suazilandia': 'África',
    'sudafrica': 'África',
    'sudan': 'África',
    'suecia': 'Europa',
    'suiza': 'Europa',
    'surinam': 'América',
    'tailandia': 'Asia',
    'tanzania': 'África',
    'tayikistan': 'Asia',
    'timor-oriental': 'Asia',
    'togo': 'África',
    'tonga': 'Oceanía',
    'trinidad-tobago': 'América',
    'tunez': 'África',
    'turkmenistan': 'Asia',
    'turquia': 'Asia',
    'tuvalu': 'Oceanía',
    'ucrania': 'Europa',
    'uganda': 'África',
    'uk': 'Europa',
    'uruguay': 'América',
    'usa': 'América',
    'uzbekistan': 'Asia',
    'vanuatu': 'Oceanía',
    'venezuela': 'América',
    'vietnam': 'Asia',
    'yemen': 'Asia',
    'yibuti': 'África',
    'zambia': 'África',
    'zimbabue': 'África',
}

# %%
df3['Continent'] = df3['Country'].map(paises_continentes1)

# %%
df3 = df3.rename(columns = {'Value' : 'Obesity Rate'})

# %%
df3
# Out:
#          Country  Year  Obesity Rate    Max    Min Continent
# 0     afganistan  2021         39.13  63.65  20.86      Asia
# 1     afganistan  2020         39.37  64.19  20.91      Asia
# 2     afganistan  2019         39.45  63.80  20.91      Asia
# 3     afganistan  2018         39.23  63.66  20.90      Asia
# 4     afganistan  2017         38.97  62.35  21.38      Asia
# ...          ...   ...           ...    ...    ...       ...
# 1129    zimbabue  2020         43.82  70.76  23.64    África
# 1130    zimbabue  2019         43.33  69.52  23.34    África
# 1131    zimbabue  2018         42.54  68.38  22.91    África
# 1132    zimbabue  2017         41.68  66.68  22.65    África
# 1133    zimbabue  2016         41.13  65.26  22.51    África
#
# [1134 rows x 6 columns]

# %%
sns.barplot(x="Continent", y="Obesity Rate", data = df3 )
plt.show()

# %%
sns.boxplot(x = 'Continent',y='Obesity Rate', data=df3)
plt.show()

# %%
sns.distplot(df3['Obesity Rate'], bins=50)
plt.show()
# Out:
# /var/folders/zc/6rc7nzhj13scy5qssxw2pjlh0000gn/T/ipykernel_2588/1148737190.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3['Obesity Rate'], bins=50)

# %%
df3 = df3.drop(columns = 'Country')
df3
# Out:
#       Year  Obesity Rate    Max    Min Continent
# 0     2021         39.13  63.65  20.86      Asia
# 1     2020         39.37  64.19  20.91      Asia
# 2     2019         39.45  63.80  20.91      Asia
# 3     2018         39.23  63.66  20.90      Asia
# 4     2017         38.97  62.35  21.38      Asia
# ...    ...           ...    ...    ...       ...
# 1129  2020         43.82  70.76  23.64    África
# 1130  2019         43.33  69.52  23.34    África
# 1131  2018         42.54  68.38  22.91    África
# 1132  2017         41.68  66.68  22.65    África
# 1133  2016         41.13  65.26  22.51    África
#
# [1134 rows x 5 columns]

# %%
df3.to_csv('Obesity_continents.csv')
