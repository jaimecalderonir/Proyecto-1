# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs

# %%
"""import pandas as pd
import requests
from bs4 import BeautifulSoup as bs

url = 'https://datosmacro.expansion.com/demografia/mortalidad'
response = requests.get(url)
soup = bs(response.content, 'html.parser')
paises = soup.find_all('tr')
(paises[1].find('a')['href']).split('/')[-1]

def get_pais (pais): 
    url = f'https://datosmacro.expansion.com/demografia/mortalidad/{pais}'
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')
    tbody = soup.find('tbody')
    tr_list = tbody.find_all('tr')
    esperanzas = []
    for tr in tr_list:
        fecha = tr.find(class_ = "fecha").text
        esp_vida_f, esp_vida_m, esp_vida_t = tr.find_all(class_ = "numero")
        esperanzas.append([pais.lower(), fecha, esp_vida_f.text, esp_vida_m.text, esp_vida_t.text])
    return esperanzas

lista_paises = []
for pais in paises[1:]: 
    name = pais.find('a')['href'].split('/')[-1]
    lista_paises.append(name)
lista_paises 

final_list = []
for pais in lista_paises: 
    list_data = get_pais(pais)
    for data in list_data:
        final_list.append(data)

df = pd.DataFrame(final_list)
df.to_csv('datos_paises.csv')
df
    
df = pd.DataFrame(get_pais('espana'))
df"""
# Out:
# 'import pandas as pd\nimport requests\nfrom bs4 import BeautifulSoup as bs\n\nurl = \'https://datosmacro.expansion.com/demografia/mortalidad\'\nresponse = requests.get(url)\nsoup = bs(response.content, \'html.parser\')\npaises = soup.find_all(\'tr\')\n(paises[1].find(\'a\')[\'href\']).split(\'/\')[-1]\n\ndef get_pais (pais): \n    url = f\'https://datosmacro.expansion.com/demografia/mortalidad/{pais}\'\n    response = requests.get(url)\n    soup = bs(response.content, \'html.parser\')\n    tbody = soup.find(\'tbody\')\n    tr_list = tbody.find_all(\'tr\')\n    esperanzas = []\n    for tr in tr_list:\n        fecha = tr.find(class_ = "fecha").text\n        esp_vida_f, esp_vida_m, esp_vida_t = tr.find_all(class_ = "numero")\n        esperanzas.append([pais.lower(), fecha, esp_vida_f.text, esp_vida_m.text, esp_vida_t.text])\n    return esperanzas\n\nlista_paises = []\nfor pais in paises[1:]: \n    name = pais.find(\'a\')[\'href\'].split(\'/\')[-1]\n    lista_paises.append(name)\nlista_p
# ...

# %%
url = 'https://datosmacro.expansion.com/demografia/esperanza-vida'
response = requests.get(url)
soup = bs(response.content, 'html.parser')

# %%
paises = soup.find_all('tr')
paises
# Out:
# [<tr class="tableheader"><th>Países</th><th>Fecha</th><th title="Esperanza de vida al nacer - Mujeres">Esperanza de vida - Mujeres</th><th title="Esperanza de vida al nacer - Hombres">Esperanza de vida - Hombres</th><th colspan="2" title="Esperanza de vida al nacer">Esperanza de vida</th><th>Var.</th></tr>,
#  <tr><td><a href="/demografia/esperanza-vida/espana" title="España - Esperanza de vida al nacer">España [+]</a></td><td class="fecha" data-value="2023-12-01">2023</td><td class="numero" data-value="86.7">86,70</td><td class="numero" data-value="81.2">81,20</td><td class="numero" data-value="84">84,00</td><td class="hbar wdsp1_2"><div class="graph_hbar" style="background-color: #F1BF00; width:98.1%;" title="84,00"></div></td><td class="numero text-pos" data-value="1.11">1,11%</td></tr>,
# ...

# %%
(paises[1].find('a')['href']).split('/')[-1]
# Out:
# 'espana'

# %%
lista_paises = []
for pais in paises[1:]: 
    name = pais.find('a')['href'].split('/')[-1]
    lista_paises.append(name)
lista_paises
# Out:
# ['espana',
#  'alemania',
#  'uk',
#  'francia',
#  'italia',
#  'portugal',
#  'usa',
#  'japon',
#  'china',
#  'andorra',
#  'emiratos-arabes-unidos',
#  'afganistan',
#  'antigua-barbuda',
#  'albania',
#  'armenia',
#  'angola',
#  'argentina',
#  'austria',
#  'australia',
#  'azerbaiyan',
#  'bosnia-herzegovina',
#  'barbados',
#  'banglades',
#  'belgica',
#  'burkina-faso',
#  'bulgaria',
#  'barein',
#  'burundi',
#  'benin',
#  'brunei',
#  'bolivia',
#  'brasil',
#  'bahamas',
#  'butan',
#  'botsuana',
#  'bielorrusia',
#  'belice',
#  'canada',
#  'republica-democratica-congo',
#  'republica-centroafricana',
#  'congo',
#  'suiza',
#  'costa-marfil',
#  'chile',
#  'camerun',
#  'colombia',
#  'costa-rica',
#  'cuba',
#  'cabo-verde',
#  'chipre',
#  'republica-checa',
#  'yibuti',
#  'dinamarca',
#  'dominica',
#  'republica-dominicana',
#  'argelia',
#  'ecuador',
#  'estonia',
#  'egipto',
#  'eritrea',
#  'etiopia',
#  'finlandia',
#  'fiyi',
#  'micronesia',
# ...

# %%
tbody = soup.find('tbody')
tr_list = tbody.find_all('tr')
tr_list
# Out:
# [<tr><td><a href="/demografia/esperanza-vida/espana" title="España - Esperanza de vida al nacer">España [+]</a></td><td class="fecha" data-value="2023-12-01">2023</td><td class="numero" data-value="86.7">86,70</td><td class="numero" data-value="81.2">81,20</td><td class="numero" data-value="84">84,00</td><td class="hbar wdsp1_2"><div class="graph_hbar" style="background-color: #F1BF00; width:98.1%;" title="84,00"></div></td><td class="numero text-pos" data-value="1.11">1,11%</td></tr>,
#  <tr><td><a href="/demografia/esperanza-vida/alemania" title="Alemania - Esperanza de vida al nacer">Alemania [+]</a></td><td class="fecha" data-value="2023-12-01">2023</td><td class="numero" data-value="83">83,00</td><td class="numero" data-value="78.3">78,30</td><td class="numero" data-value="81.2">81,20</td><td class="hbar"><div class="graph_hbar" style="background-color: #FFE000; width:94.9%;" title="81,20"></div></td><td class="numero text-pos" data-value="0.62">0,62%</td></tr>,
# ...

# %%
def get_pais (pais): 
    url = f'https://datosmacro.expansion.com/demografia/esperanza-vida/{pais}'
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')
    tbody = soup.find('tbody')
    tr_list = tbody.find_all('tr')
    esperanzas = []
    for tr in tr_list:
        fecha = tr.find(class_ = "fecha").text
        esp_vida_f, esp_vida_m, esp_vida_t = tr.find_all(class_ = "numero")
        esperanzas.append([pais.lower(), fecha, esp_vida_f.text, esp_vida_m.text, esp_vida_t.text])
    return esperanzas

df_clean = df[df[1].isin([str(year) for year in range(2016,2022)])]
df_clean

    
df = pd.DataFrame(get_pais('espana'))
df
# Out:
#          0     1      2      3      4
# 0   espana  2023  86,70  81,20  84,00
# 1   espana  2022  85,74  80,36  83,08
# 2   espana  2021  85,81  80,20  83,03
# 3   espana  2020  85,04  79,52  82,28
# 4   espana  2019  86,19  80,78  83,53
# ..     ...   ...    ...    ...    ...
# 59  espana  1964  73,14  67,79  70,40
# 60  espana  1963  72,36  67,13  69,68
# 61  espana  1962  72,08  67,08  69,52
# 62  espana  1961  71,98  67,10  69,48
# 63  espana  1960  71,66  66,68  69,11
#
# [64 rows x 5 columns]

# %%
df_clean = df[df[1].isin([str(year) for year in range(2016,2022)])]
df_clean
# Out:
#         0     1      2      3      4
# 2  espana  2021  85,81  80,20  83,03
# 3  espana  2020  85,04  79,52  82,28
# 4  espana  2019  86,19  80,78  83,53
# 5  espana  2018  85,83  80,40  83,15
# 6  espana  2017  85,71  80,32  83,05
# 7  espana  2016  85,82  80,26  83,08

# %%
final_list = []
for pais in lista_paises: 
    list_data = get_pais(pais)
    for data in list_data:
        final_list.append(data)

df = pd.DataFrame(final_list)
df.to_csv('datos_paises.csv')
df
# Out:
#               0     1      2      3      4
# 0        espana  2023  86,70  81,20  84,00
# 1        espana  2022  85,74  80,36  83,08
# 2        espana  2021  85,81  80,20  83,03
# 3        espana  2020  85,04  79,52  82,28
# 4        espana  2019  86,19  80,78  83,53
# ...         ...   ...    ...    ...    ...
# 11998  zimbabue  1964  56,91  53,08  54,99
# 11999  zimbabue  1963  56,47  52,64  54,55
# 12000  zimbabue  1962  56,02  52,14  54,07
# 12001  zimbabue  1961  55,56  51,69  53,62
# 12002  zimbabue  1960  55,25  51,25  53,24
#
# [12003 rows x 5 columns]

# %%
df_clean = df[df[1].isin([str(year) for year in range(2016,2022)])]

# %%
dfp = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/New_project/Proyecto-1/datos_paises.csv')

# %%
def get_pais (pais): 
    url = f'https://datosmacro.expansion.com/demografia/esperanza-vida/{pais}'
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')
    tbody = soup.find('tbody')
    tr_list = tbody.find_all('tr')
    esperanzas = []
    for tr in tr_list:
        fecha = tr.find(class_ = "fecha").text
        esp_vida_f, esp_vida_m, esp_vida_t = tr.find_all(class_ = "numero")
        esperanzas.append([pais.lower(), fecha, esp_vida_f.text, esp_vida_m.text, esp_vida_t.text])
    return esperanzas
    


    
dfpe = pd.DataFrame(get_pais('espana'))
dfpe.head(15)
# Out:
#          0     1      2      3      4
# 0   espana  2023  86,70  81,20  84,00
# 1   espana  2022  85,74  80,36  83,08
# 2   espana  2021  85,81  80,20  83,03
# 3   espana  2020  85,04  79,52  82,28
# 4   espana  2019  86,19  80,78  83,53
# 5   espana  2018  85,83  80,40  83,15
# 6   espana  2017  85,71  80,32  83,05
# 7   espana  2016  85,82  80,26  83,08
# 8   espana  2015  85,39  79,89  82,67
# 9   espana  2014  85,63  80,10  82,91
# 10  espana  2013  85,53  79,92  82,77
# 11  espana  2012  85,10  79,36  82,26
# 12  espana  2011  85,13  79,30  82,25
# 13  espana  2010  85,03  79,05  82,07
# 14  espana  2009  84,65  78,62  81,66

# %%
url1 = '/Users/Jaimecalderon/Desktop/IRONHACK/ASSES/Asses2/c2228.csv'
obesity = pd.read_csv(url1)
obesity['Obesity Rate'] = obesity['Value']
obesity.drop('Value', axis = 1, inplace = True)
obesity.drop('Pos', axis = 1, inplace = True)
obesity.rename(columns = {'Name' : 'Country'}, inplace=True)
obesity1 = obesity.sort_values('Country')

# %%
obesity1['Country'] = obesity1['Country'].str.lower()
obesity1['Country']
# Out:
# 181        afganistan
# 87            albania
# 115           argelia
# 0      american samoa
# 57            andorra
#             ...
# 25          venezuela
# 185           vietnam
# 120             yemen
# 173            zambia
# 142          zimbabue
# Name: Country, Length: 191, dtype: object

# %%
df_clean.columns = ['Country', 'Year', 'Life Expectancy F', 'Life Expectancy M', 'Total Life Expectancy']

df_clean.sort_index()
# Out:
#         Country  Year Life Expectancy F Life Expectancy M  \
# 2        espana  2021             85,81             80,20
# 3        espana  2020             85,04             79,52
# 4        espana  2019             86,19             80,78
# 5        espana  2018             85,83             80,40
# 6        espana  2017             85,71             80,32
# ...         ...   ...               ...               ...
# 11942  zimbabue  2020             63,86             58,13
# 11943  zimbabue  2019             63,66             58,64
# 11944  zimbabue  2018             63,59             58,97
# 11945  zimbabue  2017             62,96             58,21
# 11946  zimbabue  2016             62,42             57,96
#
#       Total Life Expectancy
# 2                     83,03
# 3                     82,28
# 4                     83,53
# 5                     83,15
# 6                     83,05
# ...                     ...
# 11942                 61,12
# 11943                 61,29
# ...

# %%
df_clean['Country']
# Out:
# 2          espana
# 3          espana
# 4          espana
# 5          espana
# 6          espana
#            ...
# 11942    zimbabue
# 11943    zimbabue
# 11944    zimbabue
# 11945    zimbabue
# 11946    zimbabue
# Name: Country, Length: 1152, dtype: object

# %%
country_mapping = {
    'afghanistan': 'afganistan',
    'albania': 'albania',
    'algeria': 'argelia',
    'american samoa': None,
    'andorra': 'andorra',
    'angola': 'angola',
    'antigua and barbuda': 'antigua-barbuda',
    'argentina': 'argentina',
    'armenia': 'armenia',
    'australia': 'australia',
    'austria': 'austria',
    'azerbaijan': 'azerbaiyan',
    'bahamas, the': 'bahamas',
    'bahrain': 'barein',
    'bangladesh': 'banglades',
    'barbados': 'barbados',
    'belarus': 'bielorrusia',
    'belgium': 'belgica',
    'belize': 'belice',
    'benin': 'benin',
    'bhutan': 'butan',
    'bolivia': 'bolivia',
    'bosnia and herzegovina': 'bosnia-herzegovina',
    'botswana': 'botsuana',
    'brazil': 'brasil',
    'brunei': 'brunei',
    'bulgaria': 'bulgaria',
    'burkina faso': 'burkina-faso',
    'burma': 'birmania',
    'burundi': 'burundi',
    'cabo verde': 'cabo-verde',
    'cambodia': 'camboya',
    'cameroon': 'camerun',
    'canada': 'canada',
    'central african republic': 'republica-centroafricana',
    'chad': 'chad',
    'chile': 'chile',
    'china': 'china',
    'colombia': 'colombia',
    'comoros': 'comoras',
    'congo, democratic republic of the': 'republica-democratica-congo',
    'congo, republic of the': 'congo',
    'cook islands': None,
    'costa rica': 'costa-rica',
    "cote d'ivoire": 'costa-marfil',
    'croatia': 'croacia',
    'cuba': 'cuba',
    'cyprus': 'chipre',
    'czech republic': 'republica-checa',
    'denmark': 'dinamarca',
    'djibouti': 'yibuti',
    'dominica': 'dominica',
    'dominican republic': 'republica-dominicana',
    'ecuador': 'ecuador',
    'egypt': 'egipto',
    'el salvador': 'el-salvador',
    'equatorial guinea': 'guinea-ecuatorial',
    'eritrea': 'eritrea',
    'estonia': 'estonia',
    'ethiopia': 'etiopia',
    'fiji': 'fiyi',
    'finland': 'finlandia',
    'france': 'francia',
    'gabon': 'gabon',
    'gambia, the': 'gambia',
    'georgia': 'georgia',
    'germany': 'alemania',
    'ghana': 'ghana',
    'greece': 'grecia',
    'grenada': 'granada',
    'guatemala': 'guatemala',
    'guinea': 'guinea',
    'guinea-bissau': 'guinea-bisau',
    'guyana': 'guyana',
    'haiti': 'haiti',
    'honduras': 'honduras',
    'hungary': 'hungria',
    'iceland': 'islandia',
    'india': 'india',
    'indonesia': 'indonesia',
    'iran': 'iran',
    'iraq': 'irak',
    'ireland': 'irlanda',
    'israel': 'israel',
    'italy': 'italia',
    'jamaica': 'jamaica',
    'japan': 'japon',
    'jordan': 'jordania',
    'kazakhstan': 'kazajistan',
    'kenya': 'kenia',
    'kiribati': 'kiribati',
    'korea, north': 'corea-del-norte',
    'korea, south': 'corea-del-sur',
    'kuwait': 'kuwait',
    'kyrgyzstan': 'kirguistan',
    'laos': 'laos',
    'latvia': 'letonia',
    'lebanon': 'libano',
    'lesotho': 'lesoto',
    'liberia': 'liberia',
    'libya': 'libia',
    'lithuania': 'lituania',
    'luxembourg': 'luxemburgo',
    'macedonia': 'macedonia',
    'madagascar': 'madagascar',
    'malawi': 'malaui',
    'malaysia': 'malasia',
    'maldives': 'maldivas',
    'mali': 'mali',
    'malta': 'malta',
    'marshall islands': 'islas-marshall',
    'mauritania': 'mauritania',
    'mauritius': 'mauricio',
    'mexico': 'mexico',
    'micronesia, federated states of': 'micronesia',
    'moldova': 'moldavia',
    'mongolia': 'mongolia',
    'montenegro': 'montenegro',
    'morocco': 'marruecos',
    'mozambique': 'mozambique',
    'namibia': 'namibia',
    'nauru': 'nauru',
    'nepal': 'nepal',
    'netherlands': 'paises-bajos',
    'new zealand': 'nueva-zelanda',
    'nicaragua': 'nicaragua',
    'niger': 'niger',
    'nigeria': 'nigeria',
    'norway': 'noruega',
    'oman': 'oman',
    'pakistan': 'pakistan',
    'palau': None,
    'panama': 'panama',
    'papua new guinea': 'papua-nueva-guinea',
    'paraguay': 'paraguay',
    'peru': 'peru',
    'philippines': 'filipinas',
    'poland': 'polonia',
    'portugal': 'portugal',
    'qatar': 'catar',
    'romania': 'rumania',
    'russia': 'rusia',
    'rwanda': 'ruanda',
    'saint kitts and nevis': 'san-cristobal-nieves',
    'saint lucia': 'santa-lucia',
    'saint vincent and the grenadines': 'san-vicente-las-granadinas',
    'samoa': 'samoa',
    'sao tome and principe': 'santo-tome-principe',
    'saudi arabia': 'arabia-saudita',
    'senegal': 'senegal',
    'serbia': 'serbia',
    'seychelles': 'seychelles',
    'sierra leone': 'sierra-leona',
    'singapore': 'singapur',
    'slovakia': 'eslovaquia',
    'slovenia': 'eslovenia',
    'solomon islands': 'islas-salomon',
    'somalia': 'somalia',
    'south africa': 'sudafrica',
    'spain': 'espana',
    'sri lanka': 'sri-lanka',
    'sudan': 'sudan',
    'suriname': 'surinam',
    'swaziland': 'suazilandia',
    'sweden': 'suecia',
    'switzerland': 'suiza',
    'syria': 'siria',
    'tajikistan': 'tayikistan',
    'tanzania': 'tanzania',
    'thailand': 'tailandia',
    'timor-leste': 'timor-oriental',
    'togo': 'togo',
    'tokelau': None,
    'tonga': 'tonga',
    'trinidad and tobago': 'trinidad-tobago',
    'tunisia': 'tunez',
    'turkey': 'turquia',
    'turkmenistan': 'turkmenistan',
    'uganda': 'uganda',
    'ukraine': 'ucrania',
    'united arab emirates': 'emiratos-arabes-unidos',
    'united kingdom': 'uk',
    'united states': 'usa',
    'uruguay': 'uruguay',
    'uzbekistan': 'uzbekistan',
    'vanuatu': 'vanuatu',
    'venezuela': 'venezuela',
    'vietnam': 'vietnam',
    'yemen': 'yemen',
    'zambia': 'zambia',
    'zimbabwe': 'zimbabue'
}

# %%
import pandas as pd

# Supongamos que tu DataFrame se llama df
df_clean['Country'] = df_clean['Country'].str.lower().map(country_mapping).fillna(df_clean['Country'])

# Verificar el resultado
df_clean
# Out:
# /var/folders/zc/6rc7nzhj13scy5qssxw2pjlh0000gn/T/ipykernel_40668/4264889614.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Country'] = df_clean['Country'].str.lower().map(country_mapping).fillna(df_clean['Country'])
#         Country  Year Life Expectancy F Life Expectancy M  \
# 2        espana  2021             85,81             80,20
# 3        espana  2020             85,04             79,52
# 4        espana  2019             86,19             80,78
# 5        espana  2018             85,83             80,40
# 6        espana  2017             85,71             80,32
# ...         ...   ...               ...               ...
# 11942  zimbabue  2020             63,86             58,13
# ...

# %%
obesity1['Country'] = obesity1['Country'].str.lower().map(country_mapping).fillna(obesity1['Country'])
obesity1
# Out:
#             Country  Obesity Rate
# 181      afganistan           2.2
# 87          albania          21.3
# 115         argelia          16.0
# 0    American Samoa          74.6
# 57          andorra          25.2
# ..              ...           ...
# 25        venezuela          30.3
# 185         vietnam           1.7
# 120           yemen          14.5
# 173          zambia           3.6
# 142        zimbabue           7.0
#
# [191 rows x 2 columns]

# %%
df_merge = pd.merge(df_clean, obesity1, on='Country', how='inner')

# %%
df_merge_clean = df_merge

# %%
df_merge_clean['Country'].unique()
# Out:
# array(['Spain', 'Germany', 'UK', 'France', 'Italy', 'Portugal', 'USA',
#        'Japan', 'China', 'Andorra', 'United Arab Emirates', 'Afghanistan',
#        'Antigua and Barbuda', 'Albania', 'Armenia', 'Angola', 'Argentina',
#        'Austria', 'Australia', 'Azerbaijan', 'Bosnia and Herzegovina',
#        'Barbados', 'Bangladesh', 'Belgium', 'Burkina Faso', 'Bulgaria',
#        'Bahrain', 'Burundi', 'Benin', 'Brunei', 'Bolivia', 'Brazil',
#        'Bahamas', 'Bhutan', 'Botswana', 'Belarus', 'Belize', 'Canada',
#        'Democratic Republic of the Congo', 'Central African Republic',
#        'Republic of the Congo', 'Switzerland', 'Ivory Coast', 'Chile',
#        'Cameroon', 'Colombia', 'Costa Rica', 'Cuba', 'Cape Verde',
#        'Cyprus', 'Czech Republic', 'Djibouti', 'Denmark', 'Dominica',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Estonia', 'Egypt',
#        'Eritrea', 'Ethiopia', 'Finland', 'Fiji', 'Micronesia', 'Gabon',
# ...

# %%
ob_year = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/New_project/Proyecto-1/IHME-GBD_2021_DATA-3e9ff72d-1.csv')
ob_year.drop(columns= ['measure_id','measure_name', 'location_id', 'sex_id', 'sex_name', 'age_id', 'age_name', 'cause_id', 'cause_name', 'rei_id', 'rei_name', 'metric_id'], inplace = True )
ob_year_f= ob_year.loc[ob_year['metric_name'] == 'Rate']
ob_year_f_r = ob_year_f.round(2)
ob_year_f_r
# Out:
#                                location_name metric_name  year      val  \
# 2      Democratic People's Republic of Korea        Rate  2016    32.14
# 5      Democratic People's Republic of Korea        Rate  2017    33.36
# 8      Democratic People's Republic of Korea        Rate  2018    34.76
# 11     Democratic People's Republic of Korea        Rate  2019    36.18
# 14     Democratic People's Republic of Korea        Rate  2020    37.70
# ...                                      ...         ...   ...      ...
# 28607          Health System Grouping Levels        Rate  2017  1485.87
# 28610          Health System Grouping Levels        Rate  2018  1522.60
# 28613          Health System Grouping Levels        Rate  2019  1557.63
# 28616          Health System Grouping Levels        Rate  2020  1592.30
# 28619          Health System Grouping Levels        Rate  2021  1627.92
#
#          upper   lower
# 2        54.35   17.37
# 5        56.19   18.18
# 8        58.59   18.76
# ...

# %%
df_drop = ob_year_f_r.loc[28532:28619].index
index_drop = list(df_drop)

# %%
df_ob_r = ob_year_f_r.drop(index = index_drop)

# %%
df_ob_r.drop(columns = 'metric_name', inplace=True)

# %%
df_ob_r_f = df_ob_r.rename(columns = {'location_name' : 'Country', 'year': 'Year', 'val' : 'Value', 'upper' : 'MAX', 'lower' : 'MIN' })

# %%
df_ob_r_f['Country'].unique()
# Out:
# array(["Democratic People's Republic of Korea", 'Global', 'East Asia',
#        'Kingdom of Cambodia', "People's Republic of China",
#        'Taiwan (Province of China)',
#        'Southeast Asia, East Asia, and Oceania', 'Southeast Asia',
#        'Republic of Maldives', "Lao People's Democratic Republic",
#        'Republic of the Philippines', 'Republic of Indonesia',
#        'Republic of the Union of Myanmar', 'Malaysia',
#        'Democratic Socialist Republic of Sri Lanka',
#        'Kingdom of Thailand', 'Republic of Fiji',
#        'Socialist Republic of Viet Nam', 'Oceania',
#        'Republic of Kiribati', 'Democratic Republic of Timor-Leste',
#        'Republic of the Marshall Islands',
#        'Federated States of Micronesia',
#        'Central Europe, Eastern Europe, and Central Asia',
#        'Independent State of Samoa', 'Kingdom of Tonga',
#        'Republic of Vanuatu', 'Independent State of Papua New Guinea',
# ...

# %%
df_merge_clean.shape
# Out:
# (1122, 6)

# %%
countries = {
    'espana': 'Spain',
    'alemania': 'Germany',
    'uk': 'UK',
    'francia': 'France',
    'italia': 'Italy',
    'portugal': 'Portugal',
    'usa': 'USA',
    'japon': 'Japan',
    'china': 'China',
    'andorra': 'Andorra',
    'emiratos-arabes-unidos': 'United Arab Emirates',
    'afganistan': 'Afghanistan',
    'antigua-barbuda': 'Antigua and Barbuda',
    'albania': 'Albania',
    'armenia': 'Armenia',
    'angola': 'Angola',
    'argentina': 'Argentina',
    'austria': 'Austria',
    'australia': 'Australia',
    'azerbaiyan': 'Azerbaijan',
    'bosnia-herzegovina': 'Bosnia and Herzegovina',
    'barbados': 'Barbados',
    'banglades': 'Bangladesh',
    'belgica': 'Belgium',
    'burkina-faso': 'Burkina Faso',
    'bulgaria': 'Bulgaria',
    'barein': 'Bahrain',
    'burundi': 'Burundi',
    'benin': 'Benin',
    'brunei': 'Brunei',
    'bolivia': 'Bolivia',
    'brasil': 'Brazil',
    'bahamas': 'Bahamas',
    'butan': 'Bhutan',
    'botsuana': 'Botswana',
    'bielorrusia': 'Belarus',
    'belice': 'Belize',
    'canada': 'Canada',
    'republica-democratica-congo': 'Democratic Republic of the Congo',
    'republica-centroafricana': 'Central African Republic',
    'congo': 'Republic of the Congo',
    'suiza': 'Switzerland',
    'costa-marfil': 'Ivory Coast',
    'chile': 'Chile',
    'camerun': 'Cameroon',
    'colombia': 'Colombia',
    'costa-rica': 'Costa Rica',
    'cuba': 'Cuba',
    'cabo-verde': 'Cape Verde',
    'chipre': 'Cyprus',
    'republica-checa': 'Czech Republic',
    'yibuti': 'Djibouti',
    'dinamarca': 'Denmark',
    'dominica': 'Dominica',
    'republica-dominicana': 'Dominican Republic',
    'argelia': 'Algeria',
    'ecuador': 'Ecuador',
    'estonia': 'Estonia',
    'egipto': 'Egypt',
    'eritrea': 'Eritrea',
    'etiopia': 'Ethiopia',
    'finlandia': 'Finland',
    'fiyi': 'Fiji',
    'micronesia': 'Micronesia',
    'gabon': 'Gabon',
    'granada': 'Grenada',
    'georgia': 'Georgia',
    'ghana': 'Ghana',
    'gambia': 'Gambia',
    'guinea': 'Guinea',
    'guinea-ecuatorial': 'Equatorial Guinea',
    'grecia': 'Greece',
    'guatemala': 'Guatemala',
    'guinea-bisau': 'Guinea-Bissau',
    'guyana': 'Guyana',
    'honduras': 'Honduras',
    'croacia': 'Croatia',
    'haiti': 'Haiti',
    'hungria': 'Hungary',
    'indonesia': 'Indonesia',
    'irlanda': 'Ireland',
    'israel': 'Israel',
    'india': 'India',
    'irak': 'Iraq',
    'iran': 'Iran',
    'islandia': 'Iceland',
    'jamaica': 'Jamaica',
    'jordania': 'Jordan',
    'kenia': 'Kenya',
    'kirguistan': 'Kyrgyzstan',
    'camboya': 'Cambodia',
    'kiribati': 'Kiribati',
    'comoras': 'Comoros',
    'san-cristobal-nieves': 'Saint Kitts and Nevis',
    'corea-del-norte': 'North Korea',
    'corea-del-sur': 'South Korea',
    'kuwait': 'Kuwait',
    'kazajistan': 'Kazakhstan',
    'laos': 'Laos',
    'libano': 'Lebanon',
    'santa-lucia': 'Saint Lucia',
    'sri-lanka': 'Sri Lanka',
    'liberia': 'Liberia',
    'lesoto': 'Lesotho',
    'lituania': 'Lithuania',
    'luxemburgo': 'Luxembourg',
    'letonia': 'Latvia',
    'libia': 'Libya',
    'marruecos': 'Morocco',
    'moldavia': 'Moldova',
    'montenegro': 'Montenegro',
    'madagascar': 'Madagascar',
    'islas-marshall': 'Marshall Islands',
    'macedonia': 'North Macedonia',
    'mali': 'Mali',
    'birmania': 'Myanmar',
    'mongolia': 'Mongolia',
    'mauritania': 'Mauritania',
    'malta': 'Malta',
    'mauricio': 'Mauritius',
    'maldivas': 'Maldives',
    'malaui': 'Malawi',
    'mexico': 'Mexico',
    'malasia': 'Malaysia',
    'mozambique': 'Mozambique',
    'namibia': 'Namibia',
    'niger': 'Niger',
    'nigeria': 'Nigeria',
    'nicaragua': 'Nicaragua',
    'paises-bajos': 'Netherlands',
    'noruega': 'Norway',
    'nepal': 'Nepal',
    'nauru': 'Nauru',
    'nueva-zelanda': 'New Zealand',
    'oman': 'Oman',
    'panama': 'Panama',
    'peru': 'Peru',
    'papua-nueva-guinea': 'Papua New Guinea',
    'filipinas': 'Philippines',
    'pakistan': 'Pakistan',
    'polonia': 'Poland',
    'paraguay': 'Paraguay',
    'catar': 'Qatar',
    'rumania': 'Romania',
    'serbia': 'Serbia',
    'rusia': 'Russia',
    'ruanda': 'Rwanda',
    'arabia-saudita': 'Saudi Arabia',
    'islas-salomon': 'Solomon Islands',
    'seychelles': 'Seychelles',
    'sudan': 'Sudan',
    'suecia': 'Sweden',
    'singapur': 'Singapore',
    'eslovenia': 'Slovenia',
    'eslovaquia': 'Slovakia',
    'sierra-leona': 'Sierra Leone',
    'senegal': 'Senegal',
    'somalia': 'Somalia',
    'surinam': 'Suriname',
    'santo-tome-principe': 'São Tomé and Príncipe',
    'el-salvador': 'El Salvador',
    'siria': 'Syria',
    'suazilandia': 'Eswatini',
    'chad': 'Chad',
    'togo': 'Togo',
    'tailandia': 'Thailand',
    'tayikistan': 'Tajikistan',
    'timor-oriental': 'East Timor',
    'turkmenistan': 'Turkmenistan',
    'tunez': 'Tunisia',
    'tonga': 'Tonga',
    'turquia': 'Turkey',
    'trinidad-tobago': 'Trinidad and Tobago',
    'tanzania': 'Tanzania',
    'ucrania': 'Ukraine',
    'uganda': 'Uganda',
    'uruguay': 'Uruguay',
    'uzbekistan': 'Uzbekistan',
    'san-vicente-las-granadinas': 'Saint Vincent and the Grenadines',
    'venezuela': 'Venezuela',
    'vietnam': 'Vietnam',
    'vanuatu': 'Vanuatu',
    'samoa': 'Samoa',
    'yemen': 'Yemen',
    'sudafrica': 'South Africa',
    'zambia': 'Zambia',
    'zimbabue': 'Zimbabwe'
}

# %%
df_merge_clean['Country'] = df_merge_clean['Country'].str.lower().map(countries).fillna(df_merge_clean['Country'])

# %%
df_merge_clean['Country'].unique()
# Out:
# array(['espana', 'alemania', 'uk', 'francia', 'italia', 'portugal', 'usa',
#        'japon', 'china', 'andorra', 'emiratos-arabes-unidos',
#        'afganistan', 'antigua-barbuda', 'albania', 'armenia', 'angola',
#        'argentina', 'austria', 'australia', 'azerbaiyan',
#        'bosnia-herzegovina', 'barbados', 'banglades', 'belgica',
#        'burkina-faso', 'bulgaria', 'barein', 'burundi', 'benin', 'brunei',
#        'bolivia', 'brasil', 'bahamas', 'butan', 'botsuana', 'bielorrusia',
#        'belice', 'canada', 'republica-democratica-congo',
#        'republica-centroafricana', 'congo', 'suiza', 'costa-marfil',
#        'chile', 'camerun', 'colombia', 'costa-rica', 'cuba', 'cabo-verde',
#        'chipre', 'republica-checa', 'yibuti', 'dinamarca', 'dominica',
#        'republica-dominicana', 'argelia', 'ecuador', 'estonia', 'egipto',
#        'eritrea', 'etiopia', 'finlandia', 'fiyi', 'micronesia', 'gabon',
#        'granada', 'georgia', 'ghana', 'gambia', 'guinea',
# ...

# %%
df_ob_r_f['Country'].unique()
list(df_ob_r_f['Country'].unique())
# Out:
# ["Democratic People's Republic of Korea",
#  'Global',
#  'East Asia',
#  'Kingdom of Cambodia',
#  "People's Republic of China",
#  'Taiwan (Province of China)',
#  'Southeast Asia, East Asia, and Oceania',
#  'Southeast Asia',
#  'Republic of Maldives',
#  "Lao People's Democratic Republic",
#  'Republic of the Philippines',
#  'Republic of Indonesia',
#  'Republic of the Union of Myanmar',
#  'Malaysia',
#  'Democratic Socialist Republic of Sri Lanka',
#  'Kingdom of Thailand',
#  'Republic of Fiji',
#  'Socialist Republic of Viet Nam',
#  'Oceania',
#  'Republic of Kiribati',
#  'Democratic Republic of Timor-Leste',
#  'Republic of the Marshall Islands',
#  'Federated States of Micronesia',
#  'Central Europe, Eastern Europe, and Central Asia',
#  'Independent State of Samoa',
#  'Kingdom of Tonga',
#  'Republic of Vanuatu',
#  'Independent State of Papua New Guinea',
#  'Solomon Islands',
#  'Republic of Armenia',
#  'Georgia',
#  'Kyrgyz Republic',
#  'Republic of Tajikistan',
# ...

# %%
df_merge_clean['Country'].nunique()
# Out:
# 187

# %%
mapping_dict = {
    "Democratic People's Republic of Korea": "North Korea",
    'Kingdom of Cambodia': 'Cambodia',
    "People's Republic of China": 'China',
    'Taiwan (Province of China)': 'Taiwan',
    'Republic of Maldives': 'Maldives',
    "Lao People's Democratic Republic": 'Laos',
    'Republic of the Philippines': 'Philippines',
    'Republic of Indonesia': 'Indonesia',
    'Republic of the Union of Myanmar': 'Myanmar',
    'Malaysia': 'Malaysia',
    'Democratic Socialist Republic of Sri Lanka': 'Sri Lanka',
    'Kingdom of Thailand': 'Thailand',
    'Republic of Fiji': 'Fiji',
    'Socialist Republic of Viet Nam': 'Vietnam',
    'Republic of Kiribati': 'Kiribati',
    'Democratic Republic of Timor-Leste': 'East Timor',
    'Republic of the Marshall Islands': 'Marshall Islands',
    'Federated States of Micronesia': 'Micronesia',
    'Independent State of Samoa': 'Samoa',
    'Kingdom of Tonga': 'Tonga',
    'Republic of Vanuatu': 'Vanuatu',
    'Independent State of Papua New Guinea': 'Papua New Guinea',
    'Solomon Islands': 'Solomon Islands',
    'Republic of Armenia': 'Armenia',
    'Georgia': 'Georgia',
    'Kyrgyz Republic': 'Kyrgyzstan',
    'Republic of Tajikistan': 'Tajikistan',
    'Republic of Azerbaijan': 'Azerbaijan',
    'Republic of Kazakhstan': 'Kazakhstan',
    'Mongolia': 'Mongolia',
    'Turkmenistan': 'Turkmenistan',
    'Republic of Uzbekistan': 'Uzbekistan',
    'Republic of Croatia': 'Croatia',
    'Republic of Albania': 'Albania',
    'Hungary': 'Hungary',
    'Montenegro': 'Montenegro',
    'Republic of Bulgaria': 'Bulgaria',
    'Czech Republic': 'Czech Republic',
    'Romania': 'Romania',
    'North Macedonia': 'North Macedonia',
    'Slovak Republic': 'Slovakia',
    'Republic of Poland': 'Poland',
    'Republic of Serbia': 'Serbia',
    'Republic of Slovenia': 'Slovenia',
    'Republic of Belarus': 'Belarus',
    'Republic of Latvia': 'Latvia',
    'Republic of Moldova': 'Moldova',
    'Ukraine': 'Ukraine',
    'Republic of Estonia': 'Estonia',
    'Republic of Lithuania': 'Lithuania',
    'Japan': 'Japan',
    'Russian Federation': 'Russia',
    'Republic of Singapore': 'Singapore',
    'Brunei Darussalam': 'Brunei',
    'Australia': 'Australia',
    'Republic of Korea': 'South Korea',
    'New Zealand': 'New Zealand',
    'Principality of Andorra': 'Andorra',
    'Kingdom of Belgium': 'Belgium',
    'Kingdom of Denmark': 'Denmark',
    'Republic of Austria': 'Austria',
    'French Republic': 'France',
    'Republic of Cyprus': 'Cyprus',
    'Republic of Finland': 'Finland',
    'Federal Republic of Germany': 'Germany',
    'Hellenic Republic': 'Greece',
    'Ireland': 'Ireland',
    'Republic of Italy': 'Italy',
    'Republic of Iceland': 'Iceland',
    'State of Israel': 'Israel',
    'Grand Duchy of Luxembourg': 'Luxembourg',
    'Republic of Malta': 'Malta',
    'Kingdom of the Netherlands': 'Netherlands',
    'Portuguese Republic': 'Portugal',
    'Kingdom of Sweden': 'Sweden',
    'United Kingdom of Great Britain and Northern Ireland': 'UK',
    'Kingdom of Norway': 'Norway',
    'Swiss Confederation': 'Switzerland',
    'Kingdom of Spain': 'Spain',
    'Argentine Republic': 'Argentina',
    'Eastern Republic of Uruguay': 'Uruguay',
    'Canada': 'Canada',
    'Republic of Chile': 'Chile',
    'United States of America': 'USA',
    'Commonwealth of the Bahamas': 'Bahamas',
    'Belize': 'Belize',
    'Commonwealth of Dominica': 'Dominica',
    'Antigua and Barbuda': 'Antigua and Barbuda',
    'Republic of Cuba': 'Cuba',
    'Barbados': 'Barbados',
    'Grenada': 'Grenada',
    'Republic of Haiti': 'Haiti',
    'Saint Lucia': 'Saint Lucia',
    'Dominican Republic': 'Dominican Republic',
    'Republic of Suriname': 'Suriname',
    'Jamaica': 'Jamaica',
    'Saint Vincent and the Grenadines': 'Saint Vincent and the Grenadines',
    'Republic of Guyana': 'Guyana',
    'Republic of Trinidad and Tobago': 'Trinidad and Tobago',
    'Republic of Peru': 'Peru',
    'Plurinational State of Bolivia': 'Bolivia',
    'Republic of Colombia': 'Colombia',
    'Republic of Ecuador': 'Ecuador',
    'Republic of El Salvador': 'El Salvador',
    'Republic of Honduras': 'Honduras',
    'Republic of Nicaragua': 'Nicaragua',
    'Republic of Costa Rica': 'Costa Rica',
    'Republic of Guatemala': 'Guatemala',
    'Bolivarian Republic of Venezuela': 'Venezuela',
    'United Mexican States': 'Mexico',
    'Federative Republic of Brazil': 'Brazil',
    'Republic of Panama': 'Panama',
    'Republic of Paraguay': 'Paraguay',
    'Kingdom of Bahrain': 'Bahrain',
    'Islamic Republic of Iran': 'Iran',
    "People's Democratic Republic of Algeria": 'Algeria',
    'Hashemite Kingdom of Jordan': 'Jordan',
    'Lebanese Republic': 'Lebanon',
    'Arab Republic of Egypt': 'Egypt',
    'Republic of Iraq': 'Iraq',
    'Kingdom of Morocco': 'Morocco',
    'State of Kuwait': 'Kuwait',
    'Sultanate of Oman': 'Oman',
    'State of Libya': 'Libya',
    'State of Qatar': 'Qatar',
    'Syrian Arab Republic': 'Syria',
    'Kingdom of Saudi Arabia': 'Saudi Arabia',
    'Republic of Turkey': 'Turkey',
    'Republic of Yemen': 'Yemen',
    'Republic of Tunisia': 'Tunisia',
    "People's Republic of Bangladesh": 'Bangladesh',
    'United Arab Emirates': 'United Arab Emirates',
    'Republic of India': 'India',
    'Islamic Republic of Afghanistan': 'Afghanistan',
    'Islamic Republic of Pakistan': 'Pakistan',
    'Kingdom of Bhutan': 'Bhutan',
    'Federal Democratic Republic of Nepal': 'Nepal',
    'Republic of Angola': 'Angola',
    'Republic of the Congo': 'Republic of the Congo',
    'Republic of Equatorial Guinea': 'Equatorial Guinea',
    'Central African Republic': 'Central African Republic',
    'Democratic Republic of the Congo': 'Democratic Republic of the Congo',
    'Union of the Comoros': 'Comoros',
    'Gabonese Republic': 'Gabon',
    'State of Eritrea': 'Eritrea',
    'Republic of Burundi': 'Burundi',
    'Republic of Kenya': 'Kenya',
    'Republic of Djibouti': 'Djibouti',
    'Republic of Malawi': 'Malawi',
    'Federal Democratic Republic of Ethiopia': 'Ethiopia',
    'Republic of Madagascar': 'Madagascar',
    'Republic of Mauritius': 'Mauritius',
    'Republic of Rwanda': 'Rwanda',
    'Federal Republic of Somalia': 'Somalia',
    'Republic of Uganda': 'Uganda',
    'Republic of Mozambique': 'Mozambique',
    'Republic of Seychelles': 'Seychelles',
    'United Republic of Tanzania': 'Tanzania',
    'Kingdom of Lesotho': 'Lesotho',
    'Republic of Zambia': 'Zambia',
    'Republic of South Africa': 'South Africa',
    'Republic of Botswana': 'Botswana',
    'Republic of Zimbabwe': 'Zimbabwe',
    'Republic of Namibia': 'Namibia',
    'Republic of Benin': 'Benin',
    'Kingdom of Eswatini': 'Eswatini',
    'Burkina Faso': 'Burkina Faso',
    'Republic of Cabo Verde': 'Cape Verde',
    "Republic of Côte d'Ivoire": 'Ivory Coast',
    'Republic of Cameroon': 'Cameroon',
    'Republic of Ghana': 'Ghana',
    'Republic of Chad': 'Chad',
    'Republic of Guinea-Bissau': 'Guinea-Bissau',
    'Republic of Mali': 'Mali',
    'Republic of the Gambia': 'Gambia',
    'Republic of Guinea': 'Guinea',
    'Republic of the Niger': 'Niger',
    'Republic of Liberia': 'Liberia',
    'Democratic Republic of Sao Tome and Principe': 'Sao Tome and Principe',
    'Islamic Republic of Mauritania': 'Mauritania',
    'Federal Republic of Nigeria': 'Nigeria',
    'Republic of Senegal': 'Senegal',
    'Togolese Republic': 'Togo',
    'Republic of Sierra Leone': 'Sierra Leone',
    'Republic of Sudan': 'Sudan',
    'Republic of South Sudan': 'South Sudan',
    'Free State': 'South Africa',
    'KwaZulu-Natal': 'South Africa',
    'Eastern Cape': 'South Africa',
    'Mpumalanga': 'South Africa',
    'Gauteng': 'South Africa',
    'Limpopo': 'South Africa',
    'North-West': 'South Africa',
    'Western Cape': 'South Africa',
    'Northern Cape': 'South Africa',
    'Alaska': 'USA',
    'Arkansas': 'USA',
    'Colorado': 'USA',
    'Alabama': 'USA',
    'Arizona': 'USA',
    'Delaware': 'USA',
    'Florida': 'USA',
    'California': 'USA',
    'Connecticut': 'USA',
    'Hawaii': 'USA',
    'District of Columbia': 'USA',
    'Idaho': 'USA',
    'Indiana': 'USA',
    'Kansas': 'USA',
    'Illinois': 'USA',
    'Louisiana': 'USA',
    'Iowa': 'USA',
    'Maryland': 'USA',
    'Kentucky': 'USA',
    'Michigan': 'USA',
    'Mississippi': 'USA',
    'Maine': 'USA',
    'Massachusetts': 'USA',
    'Montana': 'USA',
    'Nevada': 'USA',
    'Minnesota': 'USA',
    'Missouri': 'USA',
    'Nebraska': 'USA',
    'New Hampshire': 'USA',
    'New Mexico': 'USA',
    'North Carolina': 'USA',
    'New Jersey': 'USA',
    'Ohio': 'USA',
    'New York': 'USA',
    'Oregon': 'USA',
    'North Dakota': 'USA',
    'Oklahoma': 'USA',
    'Rhode Island': 'USA',
    'South Dakota': 'USA',
    'Texas': 'USA',
    'Pennsylvania': 'USA',
    'South Carolina': 'USA',
    'Tennessee': 'USA',
    'Utah': 'USA',
    'Virginia': 'USA',
    'West Virginia': 'USA',
    'Vermont': 'USA',
    'Wyoming': 'USA',
    'Washington': 'USA',
    'Wisconsin': 'USA',
    'North West England': 'UK',
    'East Midlands': 'UK',
    'North East England': 'UK',
    'East of England': 'UK',
    'South East England': 'UK',
    'Yorkshire and the Humber': 'UK',
    'West Midlands': 'UK',
    'Greater London': 'UK',
    'Wales': 'UK',
    'South West England': 'UK',
    'Aguascalientes': 'Mexico',
    'Baja California Sur': 'Mexico',
    'Coahuila': 'Mexico',
    'Baja California': 'Mexico',
    'Campeche': 'Mexico',
    'Chiapas': 'Mexico',
    'Mexico City': 'Mexico',
    'Guanajuato': 'Mexico',
    'Colima': 'Mexico',
    'Chihuahua': 'Mexico',
    'Hidalgo': 'Mexico',
    'Durango': 'Mexico',
    'México': 'Mexico',
    'Guerrero': 'Mexico',
    'Jalisco': 'Mexico',
    'Michoacán de Ocampo': 'Mexico',
    'Nayarit': 'Mexico',
    'Oaxaca': 'Mexico',
    'Morelos': 'Mexico',
    'Nuevo León': 'Mexico',
    'Querétaro': 'Mexico',
    'San Luis Potosí': 'Mexico',
    'Sonora': 'Mexico',
    'Puebla': 'Mexico',
    'Quintana Roo': 'Mexico',
    'Tamaulipas': 'Mexico',
    'Sinaloa': 'Mexico',
    'Veracruz de Ignacio de la Llave': 'Mexico',
    'Zacatecas': 'Mexico',
    'Tabasco': 'Mexico',
    'Tlaxcala': 'Mexico',
    'Yucatán': 'Mexico',
    'Aceh': 'Indonesia',
    'West Sumatra': 'Indonesia',
    'Jambi': 'Indonesia',
    'Bengkulu': 'Indonesia',
    'North Sumatra': 'Indonesia',
    'Riau': 'Indonesia',
    'Bangka-Belitung Islands': 'Indonesia',
    'South Sumatra': 'Indonesia',
    'North Kalimantan': 'Indonesia',
    'West Java': 'Indonesia',
    'Lampung': 'Indonesia',
    'Riau Islands': 'Indonesia',
    'Yogyakarta': 'Indonesia',
    'Jakarta': 'Indonesia',
    'Central Java': 'Indonesia',
    'East Java': 'Indonesia',
    'Bali': 'Indonesia',
    'East Nusa Tenggara': 'Indonesia',
    'Banten': 'Indonesia',
    'Central Kalimantan': 'Indonesia',
    'East Kalimantan': 'Indonesia',
    'West Nusa Tenggara': 'Indonesia',
    'West Kalimantan': 'Indonesia',
    'Central Sulawesi': 'Indonesia',
    'South Kalimantan': 'Indonesia',
    'Southeast Sulawesi': 'Indonesia',
    'West Sulawesi': 'Indonesia',
    'North Sulawesi': 'Indonesia',
    'South Sulawesi': 'Indonesia',
    'North Maluku': 'Indonesia',
    'Gorontalo': 'Indonesia',
    'Maluku': 'Indonesia',
    'West Papua': 'Indonesia',
    'Papua': 'Indonesia',
    'European Union': 'Europe',
    'England': 'UK',
    'Alagoas': 'Brazil',
    'Acre': 'Brazil',
    'Amapá': 'Brazil',
    'Ceará': 'Brazil',
    'Amazonas': 'Brazil',
    'Espírito Santo': 'Brazil',
    'Bahia': 'Brazil',
    'Maranhão': 'Brazil',
    'Distrito Federal': 'Brazil',
    'Goiás': 'Brazil',
    'Minas Gerais': 'Brazil',
    'Mato Grosso': 'Brazil',
    'Paraíba': 'Brazil',
    'Pernambuco': 'Brazil',
    'Mato Grosso do Sul': 'Brazil',
    'Pará': 'Brazil',
    'Rio de Janeiro': 'Brazil',
    'Paraná': 'Brazil',
    'Rondônia': 'Brazil',
    'Piaui': 'Brazil',
    'Rio Grande do Sul': 'Brazil',
    'Sergipe': 'Brazil',
    'Rio Grande do Norte': 'Brazil',
    'Roraima': 'Brazil',
    'Tocantins': 'Brazil',
    'Santa Catarina': 'Brazil',
    'São Paulo': 'Brazil',
    'Andhra Pradesh': 'India',
    'Assam': 'India',
    'Chhattisgarh': 'India',
    'Goa': 'India',
    'Arunachal Pradesh': 'India',
    'Bihar': 'India',
    'Haryana': 'India',
    'Delhi': 'India',
    'Jammu and Kashmir': 'India',
    'Karnataka': 'India',
    'Gujarat': 'India',
    'Himachal Pradesh': 'India',
    'Madhya Pradesh': 'India',
    'Jharkhand': 'India',
    'Kerala': 'India',
    'Maharashtra': 'India',
    'Meghalaya': 'India',
    'Nagaland': 'India',
    'Manipur': 'India',
    'Punjab': 'India',
    'Sikkim': 'India',
    'Odisha': 'India',
    'Mizoram': 'India',
    'Telangana': 'India',
    'Uttar Pradesh': 'India',
    'Rajasthan': 'India',
    'Tamil Nadu': 'India',
    'West Bengal': 'India',
    'Tripura': 'India',
    'Uttarakhand': 'India',
    'Rogaland': 'Norway',
    'Sweden except Stockholm': 'Sweden',
    'Møre og Romsdal': 'Norway',
    'Oslo': 'Norway',
    'Nordland': 'Norway',
    'Hokkaidō': 'Japan',
    'Aomori': 'Japan',
    'Stockholm': 'Sweden',
    'Miyagi': 'Japan',
    'Yamagata': 'Japan',
    'Iwate': 'Japan',
    'Akita': 'Japan',
    'Fukushima': 'Japan',
    'Ibaraki': 'Japan',
    'Tochigi': 'Japan',
    'Saitama': 'Japan',
    'Tōkyō': 'Japan',
    'Gunma': 'Japan',
    'Niigata': 'Japan',
    'Ishikawa': 'Japan',
    'Chiba': 'Japan',
    'Kanagawa': 'Japan',
    'Toyama': 'Japan',
    'Yamanashi': 'Japan',
    'Gifu': 'Japan',
    'Aichi': 'Japan',
    'Fukui': 'Japan',
    'Nagano': 'Japan',
    'Shizuoka': 'Japan',
    'Mie': 'Japan',
    'Kyōto': 'Japan',
    'Hyōgo': 'Japan',
    'Wakayama': 'Japan',
    'Shiga': 'Japan',
    'Nara': 'Japan',
    'Ōsaka': 'Japan',
    'Shimane': 'Japan',
    'Hiroshima': 'Japan',
    'Tottori': 'Japan',
    'Tokushima': 'Japan',
    'Ehime': 'Japan',
    'Okayama': 'Japan',
    'Yamaguchi': 'Japan',
    'Kagawa': 'Japan',
    'Kōchi': 'Japan',
    'Saga': 'Japan',
    'Kumamoto': 'Japan',
    'Miyazaki': 'Japan',
    'Fukuoka': 'Japan',
    'Nagasaki': 'Japan',
    'Ōita': 'Japan',
    'Kagoshima': 'Japan',
    'Okinawa': 'Japan',
    'Bomet': 'Kenya',
    'Baringo': 'Kenya',
    'Bungoma': 'Kenya',
    'Elgeyo-Marakwet': 'Kenya',
    'Garissa': 'Kenya',
    'Busia': 'Kenya',
    'Isiolo': 'Kenya',
    'Embu': 'Kenya',
    'Kakamega': 'Kenya',
    'HomaBay': 'Kenya',
    'Kajiado': 'Kenya',
    'Kiambu': 'Kenya',
    'Kirinyaga': 'Kenya',
    'Kericho': 'Kenya',
    'Kisumu': 'Kenya',
    'Kilifi': 'Kenya',
    'Kwale': 'Kenya',
    'Kisii': 'Kenya',
    'Kitui': 'Kenya',
    'Laikipia': 'Kenya',
    'Machakos': 'Kenya',
    'Mandera': 'Kenya',
    'Lamu': 'Kenya',
    'Meru': 'Kenya',
    'Makueni': 'Kenya',
    'Mombasa': 'Kenya',
    'Marsabit': 'Kenya',
    'Nairobi': 'Kenya',
    'Migori': 'Kenya',
    'Nandi': 'Kenya',
    "Murang'a": 'Kenya',
    'Nyamira': 'Kenya',
    'Nakuru': 'Kenya',
    'Narok': 'Kenya',
    'Nyandarua': 'Kenya',
    'Samburu': 'Kenya',
    'TaitaTaveta': 'Kenya',
    'Nyeri': 'Kenya',
    'TharakaNithi': 'Kenya',
    'Siaya': 'Kenya',
    'Turkana': 'Kenya',
    'TanaRiver': 'Kenya',
    'Vihiga': 'Kenya',
    'TransNzoia': 'Kenya',
    'WestPokot': 'Kenya',
    'UasinGishu': 'Kenya',
    'Wajir': 'Kenya',
    'Commonwealth High Income': 'Commonwealth',
    'Commonwealth': 'Commonwealth',
    'Commonwealth Low Income': 'Commonwealth',
    'Africa': 'Africa',
    'Commonwealth Middle Income': 'Commonwealth',
    'Union Territories other than Delhi': 'India',
    'America': 'America',
    'Europe': 'Europe',
    'Region of the Americas': 'Americas',
    'European Region': 'Europe',
    'Asia': 'Asia',
    'South-East Asia Region': 'Asia',
    'Western Pacific Region': 'Western Pacific',
    'African Region': 'Africa',
    'World Bank Upper Middle Income': 'World Bank',
    'Eastern Mediterranean Region': 'Eastern Mediterranean',
    'World Bank Low Income': 'World Bank',
    'G20': 'G20',
    'World Bank High Income': 'World Bank',
    'World Bank Lower Middle Income': 'World Bank',
    'OECD Countries': 'OECD',
    'African Union': 'African Union',
    'World Bank Income Levels': 'World Bank',
    'High SDI': 'SDI',
    'Low SDI': 'SDI',
    'High-middle SDI': 'SDI',
    'Four World Regions': 'World Regions',
    'Low-middle SDI': 'SDI',
    'Middle SDI': 'SDI',
    'Darlington': 'UK',
    'Stockton-on-Tees': 'UK',
    'North America': 'North America',
    'North Tyneside': 'UK',
    'Nordic Region': 'Nordic Region',
    'Northumberland': 'UK',
    'County Durham': 'UK',
    'Newcastle upon Tyne': 'UK',
    'Redcar and Cleveland': 'UK',
    'Gateshead': 'UK',
    'South Tyneside': 'UK',
    'Hartlepool': 'UK',
    'Middlesbrough': 'UK',
    'Sunderland': 'UK',
    'Stockport': 'UK',
    'Cheshire West and Chester': 'UK',
    'Cheshire East': 'UK',
    'Lancashire': 'UK',
    'Trafford': 'UK',
    'Bolton': 'UK',
    'Sefton': 'UK',
    'Bury': 'UK',
    'Cumbria': 'UK',
    'Wirral': 'UK',
    'St Helens': 'UK',
    'Oldham': 'UK',
    'Wigan': 'UK',
    'Warrington': 'UK',
    'Rochdale': 'UK',
    'Liverpool': 'UK',
    'Salford': 'UK',
    'Knowsley': 'UK',
    'Halton': 'UK',
    'Tameside': 'UK',
    'Blackburn with Darwen': 'UK',
    'Manchester': 'UK',
    'Blackpool': 'UK',
    'East Riding of Yorkshire': 'UK',
    'North Yorkshire': 'UK',
    'York': 'UK',
    'North East Lincolnshire': 'UK',
    'Calderdale': 'UK',
    'North Lincolnshire': 'UK',
    'Bradford': 'UK',
    'Kirklees': 'UK',
    'Leeds': 'UK',
    'Wakefield': 'UK',
    'Sheffield': 'UK',
    'Rotherham': 'UK',
    'Doncaster': 'UK',
    'Kingston upon Hull, City of': 'UK',
    'Barnsley': 'UK',
    'Northamptonshire': 'UK',
    'Leicestershire': 'UK',
    'Rutland': 'UK',
    'Lincolnshire': 'UK',
    'Derby': 'UK',
    'Derbyshire': 'UK',
    'Nottinghamshire': 'UK',
    'Leicester': 'UK',
    'Nottingham': 'UK',
    'Herefordshire, County of': 'UK',
    'Shropshire': 'UK',
    'Warwickshire': 'UK',
    'Solihull': 'UK',
    'Staffordshire': 'UK',
    'Coventry': 'UK',
    'Worcestershire': 'UK',
    'Stoke-on-Trent': 'UK',
    'Dudley': 'UK',
    'Telford and Wrekin': 'UK',
    'Wolverhampton': 'UK',
    'Walsall': 'UK',
    'Birmingham': 'UK',
    'Bedford': 'UK',
    'Suffolk': 'UK',
    'Sandwell': 'UK',
    'Essex': 'UK',
    'Central Bedfordshire': 'UK',
    'Thurrock': 'UK',
    'Hertfordshire': 'UK',
    'Southend-on-Sea': 'UK',
    'Cambridgeshire': 'UK',
    'Norfolk': 'UK',
    'Luton': 'UK',
    'Kensington and Chelsea': 'UK',
    'Peterborough': 'UK',
    'Richmond upon Thames': 'UK',
    'Barnet': 'UK',
    'Bromley': 'UK',
    'Redbridge': 'UK',
    'Westminster': 'UK',
    'Brent': 'UK',
    'Bexley': 'UK',
    'Havering': 'UK',
    'Merton': 'UK',
    'Sutton': 'UK',
    'Hillingdon': 'UK',
    'Kingston upon Thames': 'UK',
    'Enfield': 'UK',
    'Harrow': 'UK',
    'Hammersmith and Fulham': 'UK',
    'Greenwich': 'UK',
    'Croydon': 'UK',
    'Ealing': 'UK',
    'Wandsworth': 'UK',
    'Waltham Forest': 'UK',
    'Camden': 'UK',
    'Lewisham': 'UK',
    'Southwark': 'UK',
    'Lambeth': 'UK',
    'Newham': 'UK',
    'Hounslow': 'UK',
    'Hackney': 'UK',
    'Barking and Dagenham': 'UK',
    'Tower Hamlets': 'UK',
    'Islington': 'UK',
    'Haringey': 'UK',
    'Wokingham': 'UK',
    'Buckinghamshire': 'UK',
    'Surrey': 'UK',
    'West Berkshire': 'UK',
    'Windsor and Maidenhead': 'UK',
    'Bracknell Forest': 'UK',
    'Hampshire': 'UK',
    'Oxfordshire': 'UK',
    'Kent': 'UK',
    'Medway': 'UK',
    'West Sussex': 'UK',
    'Reading': 'UK',
    'Brighton and Hove': 'UK',
    'Portsmouth': 'UK',
    'Milton Keynes': 'UK',
    'Slough': 'UK',
    'East Sussex': 'UK',
    'Isle of Wight': 'UK',
    'Southampton': 'UK',
    'South Gloucestershire': 'UK',
    'Wiltshire': 'UK',
    'Devon': 'UK',
    'Dorset': 'UK',
    'North Somerset': 'UK',
    'Bath and North East Somerset': 'UK',
    'Poole': 'UK',
    'Somerset': 'UK',
    'Torbay': 'UK',
    'Swindon': 'UK',
    'Gloucestershire': 'UK',
    'Bournemouth': 'UK',
    'Bristol, City of': 'UK',
    'Plymouth': 'UK',
    'Tigray': 'Ethiopia',
    'Cornwall': 'UK',
    'Amhara': 'Ethiopia',
    'Somali': 'Ethiopia',
    'Afar': 'Ethiopia',
    'Southern Nations, Nationalities, and Peoples': 'Ethiopia',
    'Oromia': 'Ethiopia',
    'Benishangul-Gumuz': 'Ethiopia',
    'Gambella': 'Ethiopia',
    'Dire Dawa': 'Ethiopia',
    'Harari': 'Ethiopia',
    'Ardebil': 'Iran',
    'Addis Ababa': 'Ethiopia',
    'Alborz': 'Iran',
    'West Azarbayejan': 'Iran',
    'East Azarbayejan': 'Iran',
    'Bushehr': 'Iran',
    'Fars': 'Iran',
    'Golestan': 'Iran',
    'Chahar Mahaal and Bakhtiari': 'Iran',
    'Gilan': 'Iran',
    'Hormozgan': 'Iran',
    'Isfahan': 'Iran',
    'Hamadan': 'Iran',
    'Kermanshah': 'Iran',
    'Ilam': 'Iran',
    'Kerman': 'Iran',
    'Khorasan-e-Razavi': 'Iran',
    'Khuzestan': 'Iran',
    'North Khorasan': 'Iran',
    'South Khorasan': 'Iran',
    'Kohgiluyeh and Boyer-Ahmad': 'Iran',
    'Lorestan': 'Iran',
    'Mazandaran': 'Iran',
    'Kurdistan': 'Iran',
    'Qom': 'Iran',
    'Markazi': 'Iran',
    'Qazvin': 'Iran',
    'Sistan and Baluchistan': 'Iran',
    'Yazd': 'Iran',
    'Semnan': 'Iran',
    'Tehran': 'Iran',
    'Zanjan': 'Iran',
    'Trøndelag': 'Norway',
    'Azad Jammu & Kashmir': 'Pakistan',
    'Gilgit-Baltistan': 'Pakistan',
    'Khyber Pakhtunkhwa': 'Pakistan',
    'Balochistan': 'Pakistan',
    'Islamabad Capital Territory': 'Pakistan',
    'Sindh': 'Pakistan',
    'Vestland': 'Norway',
    'Vestfold og Telemark': 'Norway',
    'Agder': 'Norway',
    'Viken': 'Norway',
    'Innlandet': 'Norway',
    'Troms og Finnmark': 'Norway',
    'Association of Southeast Asian Nations': 'ASEAN',
    'Organization of Islamic Cooperation': 'OIC',
    'Central Africa': 'Central Africa',
    'Gulf Cooperation Council': 'GCC',
    'Brazil North': 'Brazil',
    'Sahel Region': 'Sahel',
    'Brazil Central-West': 'Brazil',
    'Brazil Southeast': 'Brazil',
    'Brazil Northeast': 'Brazil',
    'Basic Health System': 'Basic Health System',
    'Brazil South': 'Brazil',
    'Minimal Health System': 'Minimal Health System',
    'Advanced Health System': 'Advanced Health System',
    'Limited Health System': 'Limited Health System',
    'Health System Grouping Levels': 'Health System'
}

# %%
df33 = df_ob_r_f
df33['Country'] = df_ob_r_f['Country'].map(mapping_dict)
df33['Country'].nunique()
# Out:
# 212

# %%
df_ob_r_f['Country'].nunique()
# Out:
# 212

# %%
df_ob_r_f['Country'] = df_merge_clean['Country'].str.lower().map(mapping_dict).fillna(df_merge_clean['Country'])
df_merge_clean
# Out:
#        Country  Year Life Expectancy F Life Expectancy M  \
# 0        Spain  2021             85,81             80,20
# 1        Spain  2020             85,04             79,52
# 2        Spain  2019             86,19             80,78
# 3        Spain  2018             85,83             80,40
# 4        Spain  2017             85,71             80,32
# ...        ...   ...               ...               ...
# 1117  Zimbabwe  2020             63,86             58,13
# 1118  Zimbabwe  2019             63,66             58,64
# 1119  Zimbabwe  2018             63,59             58,97
# 1120  Zimbabwe  2017             62,96             58,21
# 1121  Zimbabwe  2016             62,42             57,96
#
#      Total Life Expectancy  Obesity Rate
# 0                    83,03          26.6
# 1                    82,28          26.6
# 2                    83,53          26.6
# 3                    83,15          26.6
# 4                    83,05          26.6
# ...

# %%
import pandas as pd
import numpy as np

# Supongamos que ya tienes los DataFrames df1 y df2
# Si los datos están en archivos CSV:
# df1 = pd.read_csv('archivo1.csv')
# df2 = pd.read_csv('archivo2.csv')

# Realizamos el merge de los dos DataFrames
df_merged_1 = pd.merge(df_merge_clean, df_ob_r_f, on='Country', how='outer', indicator=True)

# Creamos una máscara para identificar las filas que están solo en uno de los DataFrames
mask_not_both = df_merged_1['_merge'] != 'both'

# Asignamos NaN a las filas que no están en ambos DataFrames
df_merged_1.loc[mask_not_both, df_merged_1.columns != 'pais'] = np.nan

# Eliminamos la columna _merge ya que no la necesitamos más
df_merged_1.drop(columns=['_merge'], inplace=True)

df_merged_1
# Out:
#            Country Year_x Life Expectancy F Life Expectancy M  \
# 0      Afghanistan   2021             65,28             58,92
# 1      Afghanistan   2021             65,28             58,92
# 2      Afghanistan   2020             65,43             59,87
# 3      Afghanistan   2020             65,43             59,87
# 4      Afghanistan   2019             66,68             60,62
# ...            ...    ...               ...               ...
# 11375          NaN    NaN               NaN               NaN
# 11376          NaN    NaN               NaN               NaN
# 11377          NaN    NaN               NaN               NaN
# 11378          NaN    NaN               NaN               NaN
# 11379          NaN    NaN               NaN               NaN
#
#       Total Life Expectancy  Obesity Rate  Year_y  Value    MAX    MIN
# 0                     61,98           2.2  2020.0  18.75  29.10  10.45
# 1                     61,98           2.2  2021.0  19.32  29.96  10.88
# ...

# %%
df_merged_1.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[532], line 1
# ----> 1 df_merged_1.drop_duplicates(how='all')
#
# TypeError: DataFrame.drop_duplicates() got an unexpected keyword argument 'how'
